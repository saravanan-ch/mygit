# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanan-ch/mygit/blob/ftr_sara/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course_fee = 500

print (course_fee + 50)
# Out:
# 550

# %%
person_age = int(input("Enter driver's age:"))

if person_age >= 18:
                 print ("Person can drive")
else:
                 print ("Person can't drive")
# Out:
# Enter driver's age:18
# Person can drive

# %%
number = int(input("Enter the number:"))

if number %2 == 0:
             print ("NUmber is even")
else:
             print ("number is odd")
# Out:
# Enter the number:99
# number is odd

# %%
number = int(input("Enter the number:"))

if number == 0:
  print ("Zero")
elif number > 0:
  print ("Positive")
else:
  print ("Negative")
# Out:
# Enter the number:-5
# Negative

# %%
age = int(input("Enter the number:"))
eligible = True

if age > 18 and eligible == True:
    print ("eligible to vote")
else:
    print ("not eligible")
# Out:
# Enter the number:12
# not eligible

# %%
a = int(input("Enter the number a:"))
b = int(input("Enter the number b:"))

if a > b:
  print ("a is bigger")
else:
  print ("b is bigger")
# Out:
# Enter the number a:2
# Enter the number b:10
# b is bigger

# %%
a = int(input("Enter the number a:"))
b = int(input("Enter the number b:"))
c = int(input("Enter the number c:"))

if a>=b and a>=c:
  print ("a is bigger")
elif b>=a and b>=c:
  print ("b is bigger")
else:
  print ("c is bigger")
# Out:
# Enter the number a:1
# Enter the number b:2
# Enter the number c:3
# c is bigger

# %%
a = 10
b = 45
c = 25
d = 60
f = 30

print(max(a, b, c, d, f))
# Out:
# 60

# %%
a = 10
b = 45
c = 25
d = 60
f = 30

largest = b

if b > largest:
    largest = b

if c > largest:
    largest = c

if d > largest:
    largest = d

if f > largest:
    largest = f

print("Largest number is:", largest)
# Out:
# Largest number is: 60

# %%
Leap_year = int(input("enter the year"))

if Leap_year % 4 == 0 :
                print ("leap year")
else:
                print ("not leap year")
# Out:
# enter the year2050
# not leap year

# %%
user_password = input("Enter your password:")

password = "python123"

if user_password == password:
  print ("correct password")
else:
  print ("wrong password")
# Out:
# Enter your password:2243
# wrong password

# %%
input_number = int(input("enter the number:"))

if input_number %3==0 and input_number %5==0:
  print ("Divisible by Both 3 and 5")
elif input_number %3==0:
  print ("Divisible by Both 3")
elif input_number %5==0:
  print ("Divisible by Both 5")
else:
  print ("Not divisble by both 3 and 5")
# Out:
# enter the number:15
# Divisible by Both 3 and 5

# %%
user_age = int(input("enter your age:"))
movie_ticket = True

if user_age >= 18:
        if movie_ticket:
               print ("Can enter")
        else:
               print ("Can't enter")

else:
        print ("Can't enter")
# Out:
# enter your age:12
# Can't enter
